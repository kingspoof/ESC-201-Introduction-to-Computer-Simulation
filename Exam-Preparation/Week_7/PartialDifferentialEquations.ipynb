# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
length = 100
rho = np.zeros(length)
x = np.linspace(0, 1, length)

# define our initial conditions
positive_mask, negative_mask = np.zeros(length, dtype=bool), np.zeros(length, dtype=bool)
positive_mask[int(length/2-5):int(length/2+5)] = True
negative_mask[int(length/2-5):int(length/2+5)] = True

update_mask = np.ones(length, dtype=bool)
update_mask[positive_mask] = False
update_mask[negative_mask] = False

rho[positive_mask] = 1


plt.plot(x, rho)

# %%
def update_step(rho, update_mask)
